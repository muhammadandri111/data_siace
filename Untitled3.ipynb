# %%
print("=====TUGAS1======")
print("A-xis")
a = 20
b = 300000
c = 75000

a1 = ((a * b) + (a * c))
print("maka gaji karyawan A-xis adalah: Rp." + str(a1))
print()
print("B-log")
a = 14
b = 360000
c = 75000
a2 = ((a * b) + (a * c))
print("maka gaji karyawan B-log adalah: Rp." + str(a2))
print()
print("C-in")
a = 28
b = 475000
c = 75000
a3 = ((a * b) + (a * c))
print("maka gaji karyawan C-in adalah: Rp." + str(a3))
print()
print("D-namic")
a = 42
b = 580000
c = 75000
a4 = ((a * b) + (a * c))
print("maka gaji karyawan D-namic adalah: Rp." + str(a4))
print()
print("E-psilon")
a = 18
b = 400000
c = 75000
a5 = ((a * b) + (a * c))
print("maka gaji karyawan E-psilon adalah: Rp." + str(a5))
print()
print("========TUGAS2========")
pjk = 0.03
ast1 = 280000000
ast2 = 310000000
ast3 = 420000000
ast4 = 550000000
ast5 = 340000000
lb1 = 32500000
lb2 = 31000000
lb3 = 42000000
lb4 = 51500000
lb5 = 27000000
ut1 = 0.08
ut2 = 0.04
ut3 = 0.12
ut4 = 0.11
ut5 = 0.03

hasil = ((pjk * 32500000) + (ut1 * ast1))
print("maka total pajak A-Xis: "+str(hasil))
hasil = ((pjk * 31000000) + (ut2 * ast2))
print("maka total pajak B-Log: "+str(hasil))
hasil = ((pjk * 42000000) + (ut3 * ast3))
print("maka total pajak C-in: "+str(hasil))
hasil = ((pjk * 51500000) + (ut4 * ast4))
print("maka total pajak D-Namic: "+str(hasil))
hasil = ((pjk * 27000000) + (ut5 * ast5))
print("maka total pajak E-psilon: "+str(hasil))

print()
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ["A-Xis","B-Log","C-in","D-Namic","E-psilon"]
siswa = [23375000.0,13330000.0,51660000.0,62045000.0,11010000.0]
c = ['red','yellow','blue']
plt.title("jumlah orang di setiap pendidikan")
ax.bar(jurusan,siswa,color=c)
plt.show()
print()
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("jumlah orang di setiap pendidikan")
jurusan = ["A-Xis","B-Log","C-in","D-Namic","E-psilon"]
siswa = [23375000.0,13330000.0,51660000.0,62045000.0,11010000.0]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')

plt.show()
print()
print("============TUGAS3===========")
csr1 = 0.025
csr2 = 0.035 
ast1 = 280000000
ast2 = 310000000
ast3 = 420000000
ast4 = 550000000
ast5 = 340000000
hasil1 = (csr1 * ast1)    
print("maka csr perusahaan a adalalah: " + str(hasil1))       
hasil2 = (csr2 * ast2)    
print("maka csr perusahaan b adalalah: " + str(hasil2))  
hasil3 = (csr2 * ast3)    
print("maka csr perusahaan c adalalah: " + str(hasil3))
hasil4 = (csr2 * ast4)    
print("maka csr perusahaan d adalalah: " + str(hasil4)) 
hasil5 = (csr2 * ast5)    
print("maka csr perusahaan e adalalah: " + str(hasil5)) 
print()
import matplotlib.pyplot as plt                                                                                                                                                                                                                                                                                                
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ["A-Xis","B-Log","C-in","D-Namic","E-psilon"]
siswa = [ 7000000.0,10850000.000000002,14700000.000000002,19250000.0,11900000.000000002]
c = ['red','yellow','blue']
plt.title("csr perusahaan")
ax.bar(jurusan,siswa,color=c)
plt.show()
print()
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("jumlah orang di setiap pendidikan")
jurusan = ["A-Xis","B-Log","C-in","D-Namic","E-psilon"]
siswa =  [ 7000000.0,10850000.000000002,14700000.000000002,19250000.0,11900000.000000002]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')

plt.show()
print()
print("============TUGAS4===========")
lb1 = 32500000 * 12
lb2 = 31000000 * 12
lb3 = 42000000 * 12
lb4 = 51500000 * 12
lb5 = 27000000 * 12
print ("laba a adalah: " + str(lb1))
print ("laba b adalah: " + str(lb2))
print ("laba c adalah: " + str(lb3))
print ("laba d adalah: " + str(lb4))
print ("laba e adalah: " + str(lb5 ))
tt = ((lb1 + lb2 + lb3 + lb4 + lb5 ))
print("maka hasil laba semuanyah adalah0: "+ str(tt))
print("============TUGAS5================")
lab1 = 32500000
lab2 = 31000000 
lab3 = 42000000
lab4 = 51500000
lab5 = 27000000

ast1 = 280000000
ast2 = 310000000
ast3 = 420000000
ast4 = 550000000
ast5 = 340000000

a =  20
b =  14
c =  28
d =  42
e =  18
csr1 = 0.025
csr2 = 0.035 
hasil1 = ((lab1 *12 ) - csr1 * ast1 -(7500000 * 12) - 23375000)
print ("total gaji bersih pertahun: " +str(hasil1))
hasil2 = ((lab2 *12 ) - csr2 * ast2 -(6090000 * 12) - 13330000)
print ("total gaji bersih pertahun: " +str(hasil2))
hasil3 = ((lab3 *12 ) - csr2 * ast3 -(15400000 * 12) - 51660000)
print ("total gaji bersih pertahun: " +str(hasil3))
hasil4 = ((lab4 *12 ) - csr2 * ast4 -(27510000 * 12) -  62045000)
print ("total gaji bersih pertahun: " +str(hasil4))
hasil5 = ((lab5 *12 ) - csr2 * ast5 -(8550000 * 12) - 11010000)
print ("total gaji bersih pertahun: " +str(hasil5))
print()
import matplotlib.pyplot as plt                                                                                                                                                                                                                                                                                                
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ["A-Xis","B-Log","C-in","D-Namic","E-psilon"]
siswa = [ 269625000.0,274740000.0,252840000.0, 206585000.0,198490000.0]
c = ['red','yellow','blue']
plt.title("csr perusahaan")
ax.bar(jurusan,siswa,color=c)
plt.show()
print()
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("jumlah orang di setiap pendidikan")
jurusan = ["A-Xis","B-Log","C-in","D-Namic","E-psilon"]
siswa =  [ 269625000.0,274740000.0,252840000.0, 206585000.0,198490000.0]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')

plt.show()
# Out:
# =====TUGAS1======
# A-xis
# maka gaji karyawan A-xis adalah: Rp.7500000
#
# B-log
# maka gaji karyawan B-log adalah: Rp.6090000
#
# C-in
# maka gaji karyawan C-in adalah: Rp.15400000
#
# D-namic
# maka gaji karyawan D-namic adalah: Rp.27510000
#
# E-psilon
# maka gaji karyawan E-psilon adalah: Rp.8550000
#
# ========TUGAS2========
# maka total pajak A-Xis: 23375000.0
# maka total pajak B-Log: 13330000.0
# maka total pajak C-in: 51660000.0
# maka total pajak D-Namic: 62045000.0
# maka total pajak E-psilon: 11010000.0
# ============TUGAS3===========
# maka csr perusahaan a adalalah: 7000000.0
# maka csr perusahaan b adalalah: 10850000.000000002
# maka csr perusahaan c adalalah: 14700000.000000002
# maka csr perusahaan d adalalah: 19250000.0
# maka csr perusahaan e adalalah: 11900000.000000002
# ============TUGAS4===========
# laba a adalah: 390000000
# laba b adalah: 372000000
# laba c adalah: 504000000
# laba d adalah: 618000000
# laba e adalah: 324000000
# ...
