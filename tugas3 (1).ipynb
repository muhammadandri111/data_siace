# %%
print("===========TUGAS1===========")

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ["Paskibra","PMR","Pramuka","Futsal","Volly","Kesenian","Rohis"]
siswa = [5,18,30,7,16,19,12]
c = ['red','yellow','blue']
plt.title("siswa yang mengikuti ekstakulikuler di kelas 10")
ax.bar(jurusan,siswa,color=c)
plt.show()
print()
print("=======TUGAS2=========")
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ["Paskibra","PMR","Pramuka","Futsal","Volly","Kesenian","Rohis"]
siswa = [32,34,62,51,38,41,29]
c = ['red','yellow','blue']
plt.title("jumlah siswa yang mengikuti di setiap eskulnya")
ax.bar(jurusan,siswa,color=c)
plt.show()
print()

print("=======TUGAS3========")
fa = 7  
fb = 29 
fc = 15
va = 16 
vb = 10 
vc = 12
m = 287
tm = 45
hasil = (fa + fb + fc + va + vb + vc)
hasil2 = (m - hasil)
print(hasil)
print(hasil2)
print(tm)
hasil3 = (hasil2 / 332) * 10
hasil4 = (tm / 332) * 10
hasil5 = (hasil / 332) * 10
print(hasil3)
print(hasil4)
print(hasil5)

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("kelas 10")
jurusan = ["olahraga","mengikuti","tdk"]
siswa =  [26.81,13.55,59.63]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')


import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ["olahraga","mengikuti","tdk"]
siswa =  [26.81,13.55,59.63] 
c = ['yellow','blue','black']
plt.title("kelas 10")
ax.bar(jurusan,siswa,color=c)
plt.show()
print()
print()
print()
print()
print()
print()
print()
print()
print()

print()
print("========TUGAS4=======")
a = 17
b = 8
c = 20

hasil = (a + b) + (c)
print("maka yang tidak mengikuti eskul: " +str(hasil))
persentase = [32.7, 17.7, 44.4]
print("maka persentaseu nya adalah: " +str(persentase))

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("tidak mengikuti eskul")
jurusan = ["kelas10","kelas11","kelas12"]
siswa = [32.7, 17.7, 44.4]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')

plt.show()
print()
print("==========TUGAS5==========")
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ["Paskibra","PMR","Pramuka","Futsal","Volly","Kesenian","Rohis"]
siswa = [5,18,30,7,16,19,12]
c = ['yellow','blue','black']
plt.title("kelas 10")
ax.bar(jurusan,siswa,color=c)
plt.show()
print()
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("kelas 10")
jurusan = ["Paskibra","PMR","Pramuka","Futsal","Volly","Kesenian","Rohis"]
siswa =  [5,18,30,7,16,19,12]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')

plt.show()
print()
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ["Paskibra","PMR","Pramuka","Futsal","Volly","Kesenian","Rohis"]
siswa = [21,4,8,29,10,18,10]
c = ['yellow','blue','black']
plt.title("kelas 11")
ax.bar(jurusan,siswa,color=c)
plt.show()
print()

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("kelas 11")
jurusan = ["Paskibra","PMR","Pramuka","Futsal","Volly","Kesenian","Rohis"]
siswa =  [21,4,8,29,10,18,10]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
print()

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ["Paskibra","PMR","Pramuka","Futsal","Volly","Kesenian","Rohis"]
siswa = [6,12,24,15,12,4,7]
c = ['yellow','blue','black']
plt.title("kelas 12")
ax.bar(jurusan,siswa,color=c)
plt.show()
print()

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("kelas 12")
jurusan = ["Paskibra","PMR","Pramuka","Futsal","Volly","Kesenian","Rohis"]
siswa =  [6,12,24,15,12,4,7]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
print()
# Out:
# ===========TUGAS1===========
# =======TUGAS2=========
# =======TUGAS3========
# 89
# 198
# 45
# 5.9638554216867465
# 1.355421686746988
# 2.680722891566265
# ========TUGAS4=======
# maka yang tidak mengikuti eskul: 45
# maka persentaseu nya adalah: [32.7, 17.7, 44.4]
# ==========TUGAS5==========
