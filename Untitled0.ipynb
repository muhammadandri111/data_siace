# %%
burger = 	24000
pizza = 	52000
dimsum = 	30000
ekkado = 	7500
milkshake = 10000
eskrim = 	15000


print("===NOMER 1===")
burger1 = 6
pizza1 = 3
dimsum1 = 4
ekkado1 = 4
milkshake1 = 2
eskrim1 = 5
pesan = ((burger1 * burger) + (pizza1 * pizza) + (dimsum1 * dimsum) + (ekkado1 * ekkado) + (milkshake1 * milkshake) + (eskrim1 * eskrim))
print("jumlah semua belanjaan  :  " + str(pesan) + " RP")
per = ((burger1 + pizza1 + dimsum1 + ekkado1 + milkshake1 + eskrim1))
print("jumlah : " +str(per) + " RP")
print()
print("===NOMER 2===")
a = burger1/per * 100
b = pizza1/per * 100
c = dimsum1/per * 100
d = ekkado1/per * 100
e = milkshake1/per * 100
f = eskrim1/per * 100
print("burger : " +str(a)) 
print("pizza : " +str(b))
print("dimsum : " +str(c))
print("ekkado : " +str(d))
print("milkshake : " +str(e))
print("eskrim : " +str(f))
print()
import matplotlib.pyplot as plt
#pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
kelas12 = ['burger', 'pizza', 'dimsum', 'ekkado', 'milkshake', 'eskrim',]
kelas12a = [0.25,0.125, 0.16666666666666666, 0.16666666666666666, 0.08333333333333333, 0.20833333333333334, ]
ax.pie(kelas12a,labels=kelas12,autopct='%1.2f%%')
plt.title("PESANAN")
plt.show()
print()
print("===NOMER 3===")
print()
print("===ahmad===")
burger_ah =  4
pizza_ah =  2
ja = 7.5
ong = 2000
pas_ah = (0.70 * ((burger_ah * burger) + (pizza_ah * pizza)) + (ja * ong)) - 5000
print("pesanan ahmad : " +str(pas_ah) + "RP")
ah = 200000 - pas_ah
print ("maka kembalian ahmad adalah: " + str(ah))
print()
print("===beni===")
dimsum_be =  3
eskrim_be =  1
milkshake_be = 2
ja = 4
ong = 1800
pes_be = (0.70 * ((dimsum_be * dimsum) + (eskrim_be * eskrim) + (milkshake_be * milkshake)) + (ja * ong)) - 5000
print("pesanan beni : " +str(pes_be) + "RP")
ben = 150000 - pes_be
print ("maka kembalian beni adalah: " + str(ben))
print()
print("===citra===")
eskrim_ci =  3
ja = 8
ong = 2000
pes_ci =((eskrim_be * eskrim) + (ja * ong)) - 5000
print("pesanan citra : " +str(pes_ci) + "RP")
tra = 60000 - pes_ci
print ("maka kembalian citra adalah: " + str(tra))
print()
print("===dadang===")
dimsum_da =  1
burger_da = 2
ja = 5
ong = 1800
pes_da = (0.80 * ((burger_da * burger) + (dimsum_da * dimsum)) + (ja * ong)) - 5000
print("pesanan dadang : " +str(pes_da) + "RP")
dang = 100000 - pes_da
print ("maka kembalian dadang adalah: " + str(dang))
print()
print("===epen===")
ekkado_ep =  4
eskrim_ep =  1
pizza_ep = 1
ja = 12
ong = 2200
pes_ep = (0.70 * ((ekkado_ep * ekkado) + (eskrim_ep * eskrim) + (pizza_ep * pizza)) + (ja * ong)) - 5000
print("pesanan epen : " +str(pes_ep) + "RP")
pen = 100000 - pes_ep
print ("maka kembalian epen adalah: " + str(pen))
print()
print("===NOMER 4===")
print()
print("===ahmad===")
burger_ah =  4
pizza_ah =  2
ja = 7.5
ong = 2000
pas_ah = (0.30 * ((burger_ah * burger) + (pizza_ah * pizza))) + 5000
print("pesanan ahmad : " +str(pas_ah) + "RP")
print()


print("===beni===")
dimsum_be =  3
eskrim_be =  1
milkshake_be = 2
ja = 4
ong = 1800
pes_be = (0.30 * ((dimsum_be * dimsum) + (eskrim_be * eskrim) + (milkshake_be * milkshake))) + 5000
print("pesanan beni : " +str(pes_be) + "RP")
print()
print("===citra===")
eskrim_ci =  3
ja = 8
ong = 2000
pes_ci =(0 * (eskrim_be * eskrim)) + 5000
print("pesanan citra : " +str(pes_ci) + "RP")
print()
print("===dadang===")
dimsum_da =  2
burger_da = 1
ong = 1800
ja = 5
pes_da = (0.20 * ((burger_da * burger) + (dimsum_da * dimsum))) + 5000
print("pesanan dadang : " +str(pes_da) + "RP")

print()
print("===epen===")
ekkado_ep =  4
eskrim_ep =  1
pizza_ep = 1
ja = 12
ong = 2200
pes_ep = (0.30 * ((ekkado_ep * ekkado) + (eskrim_ep * eskrim) + (pizza_ep * pizza))) + 5000
print("pesanan epen : " +str(pes_ep) + "RP")

print()

print("====NOMER 5 ======")
print()
a = 7.5
b = 2000
c = 4
d = 1800
e = 8
f = 2000
g = 5
h = 1800
i = 12
j = 2200
smu =((a * b)+(c * d )+(e * f)+(g * h)+(i * j))
print("maka ongkir semua pembeian adalah:"+ str(smu))
# Out:
# ===NOMER 1===
# jumlah semua belanjaan  :  545000 RP
# jumlah : 24 RP
#
# ===NOMER 2===
# burger : 25.0
# pizza : 12.5
# dimsum : 16.666666666666664
# ekkado : 16.666666666666664
# milkshake : 8.333333333333332
# eskrim : 20.833333333333336
# ===NOMER 3===
#
# ===ahmad===
# pesanan ahmad : 150000.0RP
# maka kembalian ahmad adalah: 50000.0
#
# ===beni===
# pesanan beni : 89700.0RP
# maka kembalian beni adalah: 60300.0
#
# ===citra===
# pesanan citra : 26000RP
# maka kembalian citra adalah: 34000
#
# ===dadang===
# pesanan dadang : 66400.0RP
# maka kembalian dadang adalah: 33600.0
#
# ===epen===
# pesanan epen : 89300.0RP
# maka kembalian epen adalah: 10700.0
#
# ===NOMER 4===
#
# ===ahmad===
# pesanan ahmad : 65000.0RP
#
# ===beni===
# pesanan beni : 42500.0RP
#
# ===citra===
# pesanan citra : 5000RP
#
# ===dadang===
# pesanan dadang : 21800.0RP
#
# ===epen===
# pesanan epen : 34100.0RP
#
# ====NOMER 5 ======
#
# maka ongkir semua pembeian adalah:73600.0
