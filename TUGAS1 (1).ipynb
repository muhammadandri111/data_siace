# %%
Beras = 11400
Minyak = 12700
Ayam =  3400
Telur = 21800
popok = 27000
sabun_cuci =  1800
Buah_Anggur = 3800
Roti_tawar =  8500
Tissu = 6400
Mie_Instan =  2200

print("belanjaan tia")
beras_tia = 4
ayam_tia = 2
telur_tia = 3
sabun_cuci_tia = 5
Buah_Anggur_tia = 4
Roti_tawar_tia = 2
Mie_Instan_tia = 12 

jb_tia = ((beras_tia * Beras) + (ayam_tia * (Ayam * 10) ) + (telur_tia * Telur ) + (sabun_cuci_tia * sabun_cuci) + (Buah_Anggur_tia * Buah_Anggur) + (Roti_tawar_tia *   Roti_tawar) + (Mie_Instan_tia * Mie_Instan))
print("maka jumlah belanjan tia "+ str(jb_tia) + " rupiah")
diskon = 85
jb_diskon_tia = (jb_tia / 100) * diskon
print("maka jumlah belanjaan tia setelah dapat diskon" + str(jb_diskon_tia))
print()

print("belanjaan hana")
minyak_hana = 2
ayam_hana = 5
telur_hana = 1.5
sabun_hana = 3
buah_hana = 8
Roti_hana = 3
tisu_hana = 2
mie_hana = 20



jb_hana = (minyak_hana * Minyak) + (ayam_hana * Ayam) + (telur_hana * Telur) + (sabun_hana * sabun_cuci) + (buah_hana * Buah_Anggur) + (Roti_hana * Roti_tawar) + (tisu_hana * Tissu) + (mie_hana * Mie_Instan)
print("maka jumlah belanjan tia "+ str(jb_hana) + " rupiah")
diskon = 90
jb_diskon_hana = (jb_hana / 100) * diskon
print("maka jumlah belanjaan hana setelah dapat diskon" + str(jb_diskon_hana))

print()
print("belanjaan widia")
beras_widia = 1
minyak_widia = 1
telur_widia = 1
buah_widia = 5
tisu_widia = 3
mie_widia = 16

jb_widia = (beras_widia * Beras) + (minyak_widia * Minyak) + (telur_widia * Telur) + (buah_widia * Buah_Anggur) + (tisu_widia * Tissu) + (mie_widia* Mie_Instan)
print("maka jumlah belanjan widia "+ str(jb_widia) + " rupiah")


print()
print("belanjaan romi")
minyak_romi = 3
telur_romi = 2
popok_romi = 4
sabun_romi = 8
mie_romi = 8

jb_romi = (minyak_romi * Minyak) + (telur_romi * Telur) + (popok_romi * popok) + (sabun_romi * sabun_cuci) + (mie_romi * Mie_Instan)
print("maka jumlah belanjan romi "+ str(jb_romi) + " rupiah")
diskon = 85
jb_diskon_romi = (jb_romi / 100) * diskon
print("maka jumlah belanjaan romi setelah dapat diskon" + str(jb_diskon_romi))

print()
print("belanjaan samsul")
ayam_samsul = 3
telur_samsul = 4
popok_samsul = 2
buah_samsul = 7
tisu_samsul = 5
mie_samsul = 10

jb_samsul = ((ayam_samsul * (Ayam * 10)) + (telur_samsul * Telur) + (popok_samsul * popok) + (buah_samsul * Buah_Anggur) + (tisu_samsul * Tissu) + (mie_samsul * Mie_Instan))
print("maka jumlah belanjan samsul "+ str(jb_samsul) + " rupiah")
diskon = 75
jb_diskon_samsul = (jb_samsul / 100) * diskon
print("maka jumlah belanjaan samsul setelah dapat diskon" + str(jb_diskon_samsul))

print()
print("belanjaan dimas")
ayam_dimas = 5
popok_dimas = 5
sabun_dimas = 4
buah_dimas = 3
roti_dimas = 5
mie_dimas = 6

jb_dimas = ((ayam_dimas * (Ayam * 10)) + (popok_dimas * popok) + (sabun_dimas * sabun_cuci) + (buah_dimas * Buah_Anggur) + (roti_dimas * Roti_tawar) + (mie_dimas * Mie_Instan))
print("maka jumlah belanjan dimas "+ str(jb_dimas) + " rupiah")
diskon = 75
jb_diskon_dimas = (jb_dimas / 100) * diskon
print("maka jumlah belanjaan dimas setelah dapat diskon" + str(jb_diskon_dimas))
print()
belanjaan = ("tia","hana","widia","romi","samsul","dimas")
max = 284475
print("Siapa yang belanjaan nya paling besar adalah: " + belanjaan[5]+ ":" + str(max))
tenpersen = 173880
print("Siapa saja yang mendapatkan diskon 10% adalah: " + belanjaan[1] + ":" + str(tenpersen))
# Out:
# belanjaan tia
# maka jumlah belanjan tia 246600 rupiah
# maka jumlah belanjaan tia setelah dapat diskon209610.0
#
# belanjaan hana
# maka jumlah belanjan tia 193200.0 rupiah
# maka jumlah belanjaan hana setelah dapat diskon173880.0
#
# belanjaan widia
# maka jumlah belanjan widia 119300 rupiah
#
# belanjaan romi
# maka jumlah belanjan romi 221700 rupiah
# maka jumlah belanjaan romi setelah dapat diskon188445.0
#
# belanjaan samsul
# maka jumlah belanjan samsul 323800 rupiah
# maka jumlah belanjaan samsul setelah dapat diskon242850.0
#
# belanjaan dimas
# maka jumlah belanjan dimas 379300 rupiah
# maka jumlah belanjaan dimas setelah dapat diskon284475.0
#
# Siapa yang belanjaan nya paling besar adalah: dimas:284475
# Siapa saja yang mendapatkan diskon 10% adalah: hana:173880
