# %%
from numpy import indices
print("===TUGAS1====")
a = 5
b = 18
c = 30
d = 7
e = 16
f = 19
g = 12
print("maka jumlah siswa yang mengikuti eskul di kelas 10 dalah : " +str(a+b+c+d+e+f+g))
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
usai = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
orla = [5 ,18, 30, 7, 16, 19, 12]
c = ['orange','yellow', 'blue']
plt.title("JUMLAH ORANG DI SETIAP PENDIDIKAN")
ax.bar(usai,orla, color=c)
plt.show()
print()


print("===TUGAS2===")
a = 5
b = 21	
c = 6
print("maka jumlah eskul paskibra : " +str(a+b+c))
a = 18
b = 4	
c = 12
print("maka jumlah eskul pmr : " +str(a+b+c)) 
a = 30
b = 8	
c = 24
print("maka jumlah eskul pramuka : " +str(a+b+c))
a = 7
b = 29	
c = 15
print("maka jumlah eskul futsal : " +str(a+b+c))
a = 16
b = 10
c = 12
print("maka jumlah eskul polly : " +str(a+b+c))
a = 19
b = 18	
c = 4
print("maka jumlah eskul kesenian : " +str(a+b+c))
a = 12
b = 10
c = 7
print("maka jumlah eskul rohis : " +str(a+b+c))
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
sekul = ['paskibra', 'pmr', 'pramuka', 'futsal', 'volly', 'kesenian', 'rohis']
orr = [32 ,34, 62, 51, 38, 41, 29]
c = ['orange','yellow', 'blue']
plt.title("JUMLAH ORANG DI SETIAP PENDIDIKAN")
ax.bar(sekul,orr, color=c)
plt.show()
print("===TUGAS3===")
pa = 32
pm = 34
pr = 62
ke = 41
ro = 29
print("jumlah seluruh skul tanpa olahraga : " +str(pa+pm+pr+ke+ro))
fu = 51
po = 38
print("jumlah seluruh eskul olahraga : " +str(fu+po))
a = 17
b = 8
c = 20
print("jumlah yang tidak mengikuti eskul : " +str(a+b+c))
print()
hasil1 = 198
hasil2 = 89
hasil3 = 45
hasill = 332
print("hasil seluruh : " +str(hasil1+hasil2+hasil3))
print()
print("bagi hasil1 :" +str(hasil1/hasill))
print("bagi hasil1 :" +str(hasil2/hasill))
print("bagi hasil1 :" +str(hasil3/hasill))
print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
osss = ['tidak mengikuti', 'mengikuti', 'olahraga']
jull = [13 ,26,59 ]
c = ['orange','yellow', 'blue']
plt.title("KATEGORI ESKUL")
ax.bar(osss,jull, color=c)
plt.show()
print()
import matplotlib.pyplot as plt
#pie chart

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['tidak mengikuti', 'mengikuti', 'olahraga']
siswa = [13 ,26,59]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.title("KATEGORI ESKUL")
plt.show()
print()
print("===TUGAS4===")
a = 17
b = 8	
c = 20
d = 45
print("hasil tidak mengikuti : " +str(a+b+c))
print()
print("presentase : "+str(a/d))
print("presentase : "+str(b/d))
print("presentase : "+str(c/d))
print()
import matplotlib.pyplot as plt
#pie chart

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['kelas 10', 'kelas 11', 'kelas 12']
siswa = [37, 17, 44]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.title("DATA PPDB SMK AL MADANI GARUT")
plt.show()
print()
print("===SOA===")

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
kelas10 = ['paskibra', 'pmr', 'pramuka', 'futsal', 'polly', 'kesenian', 'rohis']
kelas10a = [5, 18, 30, 7, 16, 19, 12 ]
c = ['orange','yellow', 'blue']
plt.title("ESKUL KELAS 10")
ax.bar(kelas10,kelas10a, color=c)
plt.show()
print()
import matplotlib.pyplot as plt
#pie chart

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
kelas10 = ['paskibra', 'pmr', 'pramuka', 'futsal', 'polly', 'kesenian', 'rohis']
kelas10a = [5, 18, 30, 7, 16, 19, 12]
ax.pie(kelas10a,labels=kelas10,autopct='%1.2f%%')
plt.title("ESKUL KELAS 10")
plt.show()
print("===11===")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
kelas11 = ['paskibra', 'pmr', 'pramuka', 'futsal', 'polly', 'kesenian', 'rohis']
kelas11a = [21, 4, 8, 29, 10, 18, 10 ]
c = ['orange','yellow', 'blue']
plt.title("ESKUL KELAS 11")
ax.bar(kelas10,kelas10a, color=c)
plt.show()
print()
import matplotlib.pyplot as plt
#pie chart

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
kelas11 = ['paskibra', 'pmr', 'pramuka', 'futsal', 'polly', 'kesenian', 'rohis']
kelas11a = [21, 4, 8, 29, 10, 18, 10]
ax.pie(kelas11a,labels=kelas11,autopct='%1.2f%%')
plt.title("ESKUL KELAS 11")
plt.show()
print("===12===")
6
12
24
15
12
4
7
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
kelas12 = ['paskibra', 'pmr', 'pramuka', 'futsal', 'polly', 'kesenian', 'rohis']
kelas12a = [6, 12, 24, 15, 12, 4, 7 ]
c = ['orange','yellow', 'blue']
plt.title("ESKUL KELAS 12")
ax.bar(kelas12,kelas12a, color=c)
plt.show()
print()
import matplotlib.pyplot as plt
#pie chart

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
kelas12 = ['paskibra', 'pmr', 'pramuka', 'futsal', 'polly', 'kesenian', 'rohis']
kelas12a = [6, 12, 24, 15, 12, 4, 7]
ax.pie(kelas12a,labels=kelas12,autopct='%1.2f%%')
plt.title("ESKUL KELAS 12")
plt.show()
# Out:
# ===SOAL NO 1====
# maka jumlah siswa yang mengikuti eskul di kelas 10 dalah : 107
# ===SOAL NO 2===
# maka jumlah eskul paskibra : 32
# maka jumlah eskul pmr : 34
# maka jumlah eskul pramuka : 62
# maka jumlah eskul futsal : 51
# maka jumlah eskul polly : 38
# maka jumlah eskul kesenian : 41
# maka jumlah eskul rohis : 29
# ===SOAL NO 3===
# jumlah seluruh skul tanpa olahraga : 198
# jumlah seluruh eskul olahraga : 89
# jumlah yang tidak mengikuti eskul : 45
#
# hasil seluruh : 332
#
# bagi hasil1 :0.5963855421686747
# bagi hasil1 :0.2680722891566265
# bagi hasil1 :0.1355421686746988
# ===SOAL NO 4===
# hasil tidak mengikuti : 45
#
# presentase : 0.37777777777777777
# presentase : 0.17777777777777778
# presentase : 0.4444444444444444
# ===SOAL NO 5===
# ===11===
# ===12===
